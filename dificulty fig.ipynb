# %%
import matplotlib.pyplot as plt

# %%
dificulty=[1,2,3,4,5,6]
time=[0.0,0.008054, 0.01206707,0.01003503,29.20737,1415.58]
transaction=[15,518,2357,2425,8894382,465256774]

# %%
plt.xlabel("Dificulty")
plt.ylabel("Time(sec)")
plt.plot(dificulty,time,label="Time")

#plt.plot(dificulty,transaction,label="Transaction")
#plt.plot(time,transaction,label="Transaction")
plt.legend()
plt.grid()
plt.show()
